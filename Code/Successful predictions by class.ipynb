# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from typing_extensions import runtime_checkable
import os
import pandas as pd
os.chdir('/content/drive/MyDrive/TFG')

dfTrueLabel = pd.read_csv('testPreprocess.csv')['label']
print(dfTrueLabel[0])
for ruta in os.listdir(os.getcwd()):
      if os.path.isdir(os.getcwd()+'/'+ruta) == False and 'tags' in ruta:
        print(ruta)
        dicAciertos={0:0,1:0,2:0,3:0}
        dfPredictLabel = pd.read_csv(ruta)
        for j in dfPredictLabel.index:
          if dfPredictLabel['label'][j] == dfTrueLabel[j]:
            dicAciertos[dfTrueLabel[j]] += 1
        print(dicAciertos)

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import pandas as pd
os.chdir('/content/drive/MyDrive/TFG')


for ruta in os.listdir(os.getcwd()):
      if os.path.isdir(os.getcwd()+'/'+ruta) == False and 'tags' in ruta:
        print(ruta)
        dfPredictLabel = pd.read_csv(ruta)
        print(dfPredictLabel['label'].value_counts())
